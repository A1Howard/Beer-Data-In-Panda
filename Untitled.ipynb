# %%
import pandas as pd
import numpy as np

# %%
filename = 'Inventories/2018-02-28_12:35:40.880574.csv'
beer = pd.read_csv(filename)
beer = beer.iloc[:, 0:7]
beer.describe()
# Out:
#        Quantity_Available       Retail  Case Retail    Case Pack
# count         7770.000000  7770.000000  7770.000000  7770.000000
# mean             5.048465    36.261923    62.680597     3.954569
# std             25.443075    49.293842    51.498008     4.150021
# min             -8.000000     0.000000     0.000000     1.000000
# 25%              0.000000    10.750000    33.990000     1.000000
# 50%              0.000000    15.950000    41.990000     2.000000
# 75%              4.000000    36.990000    75.990000     4.000000
# max           1045.170000   999.990000   999.990000    24.000000

# %%
beer.corr()
# Out:
#                     Quantity_Available    Retail  Case Retail  Case Pack
# Quantity_Available            1.000000 -0.093156    -0.060359   0.077082
# Retail                       -0.093156  1.000000     0.724750  -0.370262
# Case Retail                  -0.060359  0.724750     1.000000   0.208957
# Case Pack                     0.077082 -0.370262     0.208957   1.000000

# %%
df = pd.DataFrame(d)
df
# Out:
#      Case Pack Case Retail Price        Category  \
# 0          "1"        "159.9500"         "CIDER"
# 1          "1"        "153.5000"         "CIDER"
# 2          "1"        "137.9500"         "CIDER"
# 3          "1"         "59.9900"         "CIDER"
# 4          "1"         "73.9900"         "CIDER"
# 5          "1"         "39.9900"         "CIDER"
# 6          "1"         "39.9900"         "CIDER"
# 7          "1"         "73.9500"         "CIDER"
# 8          "1"         "83.9900"         "CIDER"
# 9          "1"         "74.9900"         "CIDER"
# 10         "2"         "32.9900"         "CIDER"
# 11         "2"         "19.9700"         "CIDER"
# 12         "2"         "40.9900"         "CIDER"
# 13         "2"         "36.2900"         "CIDER"
# 14         "2"         "29.9900"         "CIDER"
# 15         "2"         "36.4900"         "CIDER"
# 16         "2"         "41.9900"         "CIDER"
# 17         "2"         "35.9900"         "CIDER"
# ...
